# %% [markdown]
# <a href="https://colab.research.google.com/github/gokulmaster918-dev/Deep-Learning/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# Training data
X = np.array([
    [0, 0],
    [0, 1],
    [1, 0],
    [1, 1]
])

# Output (AND gate)
y = np.array([0, 0, 0, 1])


# Create Neural Network
model = Sequential([
    Dense(4, input_dim=2, activation='relu'),
    Dense(1, activation='sigmoid')
])

# Compile the model
model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)

# Train the data
model.fit(X, y, epochs=100, verbose=1)

# Test
prediction = model.predict(X)

print("Predictions:")
print(prediction)
# Out:
# /usr/local/lib/python3.13/dist-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.7500 - loss: 0.6572
# Epoch 2/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.7500 - loss: 0.6563
# Epoch 3/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.7500 - loss: 0.6555
# Epoch 4/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.7500 - loss: 0.6546
# Epoch 5/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.7500 - loss: 0.6538
# Epoch 6/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.7500 - loss: 0.6529
# Epoch 7/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.7500 - loss: 0.6521
# Epoch 8/100
# ...

# %%
import zipfile
import os
import pandas as pd
import numpy as np

zip_file_path = '/content/archive (2).zip'
output_dir = '/content/unzipped_data'

# Create the output directory if it doesn't exist
os.makedirs(output_dir, exist_ok=True)

# Unzip the file
with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
    zip_ref.extractall(output_dir)

print(f"'{zip_file_path}' unzipped to '{output_dir}'.")
print("Contents of the unzipped directory:")
for root, dirs, files in os.walk(output_dir):
    for name in files:
        print(os.path.join(root, name))

# %% [markdown]
# Now that the data is unzipped, let's load it into a Pandas DataFrame. You might need to adjust the `csv_file_path` and column names (`feature_columns`, `target_column`) based on the actual contents of your zip file.

# %%
# Assuming your dataset is a CSV file named 'data.csv' inside the unzipped folder
# IMPORTANT: Adjust 'csv_file_path', 'feature_columns', and 'target_column' as per your actual dataset.
csv_file_path = os.path.join(output_dir, 'data.csv') # e.g., 'your_dataset_name.csv'

# Load the dataset
try:
    df = pd.read_csv(csv_file_path)
    print("Dataset loaded successfully. First 5 rows:")
    display(df.head())
except FileNotFoundError:
    print(f"Error: CSV file not found at {csv_file_path}. Please check the filename in the unzipped directory.")
except Exception as e:
    print(f"An error occurred while loading the CSV: {e}")


# --- Prepare X (features) and y (target) ---
# IMPORTANT: Adjust these column names based on your actual data.
# For example, if the last column is your target:
if 'df' in locals() and not df.empty:
    # Example: Assuming all but the last column are features, and the last is the target
    # If your data is specifically for a binary classification like the AND gate example,
    # ensure your features are numeric (e.g., 0s and 1s) and your target is binary (0 or 1).
    feature_columns = df.columns[:-1].tolist() # All columns except the last one
    target_column = df.columns[-1] # The last column

    # Convert DataFrame columns to numpy arrays
    X_new = df[feature_columns].values
    y_new = df[target_column].values

    print(f"\nFeatures (X_new) shape: {X_new.shape}")
    print(f"Target (y_new) shape: {y_new.shape}")
    print("First 5 rows of X_new:\n", X_new[:5])
    print("First 5 rows of y_new:\n", y_new[:5])
else:
    print("Cannot prepare X and y as the DataFrame was not loaded.")

# %%
def neural_network_transfer_function(input_data, model):
    """
    Applies the trained neural network model to new input data.

    Args:
        input_data (np.array): A 2D NumPy array where each row represents an input
                                (e.g., [[0, 1], [1, 1]]).
        model (keras.Model): The trained Keras neural network model.

    Returns:
        np.array: The predictions from the neural network for the given input_data.
    """
    # Ensure the input data has the correct shape for the model
    # If it's a single input, reshape it to be a 2D array
    if input_data.ndim == 1:
        input_data = input_data.reshape(1, -1)
    return model.predict(input_data)

print("Neural network transfer function defined.")
# Out:
# Neural network transfer function defined.

# %% [markdown]
# ### Demonstration of the Transfer Function

# %%
import numpy as np

# Test the transfer function with new inputs
new_inputs = np.array([
    [0, 0], # Expected: close to 0
    [0, 1], # Expected: close to 0
    [1, 0], # Expected: close to 0
    [1, 1], # Expected: close to 1
    [0.5, 0.5] # Example of a new, unseen input
])

# Pass the 'model' object to the transfer function
results = neural_network_transfer_function(new_inputs, model)

print("\nResults from the transfer function:")
for i, res in enumerate(results):
    print(f"Input: {new_inputs[i]}, Output: {res[0]:.4f}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1301/2462258967.py in <cell line: 0>()
#      11
#      12 # Pass the 'model' object to the transfer function
# ---> 13 results = neural_network_transfer_function(new_inputs, model)
#      14
#      15 print("\nResults from the transfer function:")
#
# NameError: name 'model' is not defined

# %%
def neural_network_transfer_function(input_data, model):
    """
    Applies the trained neural network model to new input data.

    Args:
        input_data (np.array): A 2D NumPy array where each row represents an input
                                (e.g., [[0, 1], [1, 1]]).
        model (keras.Model): The trained Keras neural network model.

    Returns:
        np.array: The predictions from the neural network for the given input_data.
    """
    # Ensure the input data has the correct shape for the model
    # If it's a single input, reshape it to be a 2D array
    if input_data.ndim == 1:
        input_data = input_data.reshape(1, -1)
    return model.predict(input_data)

print("Neural network transfer function defined.")
# Out:
# Neural network transfer function defined.

# %% [markdown]
# ### Demonstration of the Transfer Function

# %%
import numpy as np

# Test the transfer function with new inputs
new_inputs = np.array([
    [0, 0], # Expected: close to 0
    [0, 1], # Expected: close to 0
    [1, 0], # Expected: close to 0
    [1, 1], # Expected: close to 1
    [0.5, 0.5] # Example of a new, unseen input
])

# Pass the 'model' object to the transfer function
results = neural_network_transfer_function(new_inputs, model)

print("\nResults from the transfer function:")
for i, res in enumerate(results):
    print(f"Input: {new_inputs[i]}, Output: {res[0]:.4f}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1301/2462258967.py in <cell line: 0>()
#      11
#      12 # Pass the 'model' object to the transfer function
# ---> 13 results = neural_network_transfer_function(new_inputs, model)
#      14
#      15 print("\nResults from the transfer function:")
#
# NameError: name 'model' is not defined

# %%
def neural_network_transfer_function(input_data, model):
    """
    Applies the trained neural network model to new input data.

    Args:
        input_data (np.array): A 2D NumPy array where each row represents an input
                                (e.g., [[0, 1], [1, 1]]).
        model (keras.Model): The trained Keras neural network model.

    Returns:
        np.array: The predictions from the neural network for the given input_data.
    """
    # Ensure the input data has the correct shape for the model
    # If it's a single input, reshape it to be a 2D array
    if input_data.ndim == 1:
        input_data = input_data.reshape(1, -1)
    return model.predict(input_data)

print("Neural network transfer function defined.")
import numpy as np

# Test the transfer function with new inputs
new_inputs = np.array([
    [0, 0], # Expected: close to 0
    [0, 1], # Expected: close to 0
    [1, 0], # Expected: close to 0
    [1, 1], # Expected: close to 1
    [0.5, 0.5] # Example of a new, unseen input
])

# Pass the 'model' object to the transfer function
results = neural_network_transfer_function(new_inputs, model)

print("\nResults from the transfer function:")
for i, res in enumerate(results):
    print(f"Input: {new_inputs[i]}, Output: {res[0]:.4f}")
# Out:
# Neural network transfer function defined.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1301/3486601980.py in <cell line: 0>()
#      30
#      31 # Pass the 'model' object to the transfer function
# ---> 32 results = neural_network_transfer_function(new_inputs, model)
#      33
#      34 print("\nResults from the transfer function:")
#
# NameError: name 'model' is not defined
