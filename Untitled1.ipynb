# %% [markdown]
# <a href="https://colab.research.google.com/github/gokulmaster918-dev/Deep-Learning/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import zipfile
import os

zip_file_path = '/content/archive (2).zip'
extraction_path = '/content/'

# Create the extraction directory if it doesn't exist
os.makedirs(extraction_path, exist_ok=True)

with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
    zip_ref.extractall(extraction_path)

print(f"'{zip_file_path}' extracted to '{extraction_path}'")

# Verify the extracted content (optional)
# You might need to adjust TRAIN_DIR and TEST_DIR if the extracted path is different.
# For example, if it extracts into a folder named 'Combined Dataset' inside '/content/',
# then TRAIN_DIR should be '/content/Combined Dataset/train'
# Let's check the contents to confirm the path structure.
print("Content of /content/:")
for item in os.listdir('/content/'):
    print(f"- {item}")
# Out:
# ---------------------------------------------------------------------------
# BadZipFile                                Traceback (most recent call last)
# /tmp/ipykernel_696/1854417547.py in <cell line: 0>()
#       8 os.makedirs(extraction_path, exist_ok=True)
#       9
# ---> 10 with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
#      11     zip_ref.extractall(extraction_path)
#      12
#
# /usr/lib/python3.13/zipfile/__init__.py in __init__(self, file, mode, compression, allowZip64, compresslevel, strict_timestamps, metadata_encoding)
#    1405         try:
#    1406             if mode == 'r':
# -> 1407                 self._RealGetContents()
#    1408             elif mode in ('w', 'x'):
#    1409                 # set the modified flag so central directory gets written
#
# /usr/lib/python3.13/zipfile/__init__.py in _RealGetContents(self)
#    1472             raise BadZipFile("File is not a zip file")
#    1473         if not endrec:
# ...

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.applications import EfficientNetB0
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint

print("TensorFlow version:", tf.__version__)

# Global constants
IMG_SIZE = (224, 224)
BATCH_SIZE = 32
SEED = 42
NUM_CLASSES = 4
EPOCHS_INITIAL = 10
EPOCHS_FINE = 1

# Directory definitions
TRAIN_DIR = "/content/Combined Dataset/train"
TEST_DIR = "/content/Combined Dataset/test"

print("Train directory exists:", os.path.exists(TRAIN_DIR))
print("Test directory exists:", os.path.exists(TEST_DIR))

# Dataset loading
train_ds = tf.keras.utils.image_dataset_from_directory(
    TRAIN_DIR,
    validation_split=0.20,
    subset="training",
    seed=SEED,
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    label_mode="categorical"
)

val_ds = tf.keras.utils.image_dataset_from_directory(
    TRAIN_DIR,
    validation_split=0.20,
    subset="validation",
    seed=SEED,
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    label_mode="categorical"
)

test_ds = tf.keras.utils.image_dataset_from_directory(
    TEST_DIR,
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    shuffle=False,
    label_mode="categorical"
)

# Class names extraction
class_names = train_ds.class_names
print("Classes:")
for i, name in enumerate(class_names):
    print(i, ":", name)

# Dataset prefetching
AUTOTUNE = tf.data.AUTOTUNE
train_ds = train_ds.prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.prefetch(buffer_size=AUTOTUNE)
test_ds = test_ds.prefetch(buffer_size=AUTOTUNE)

# Data sample visualization
plt.figure(figsize=(12, 10))
for images, labels in train_ds.take(1):
    for i in range(9):
        plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        label_index = np.argmax(labels[i].numpy())
        plt.title(class_names[label_index])
        plt.axis("off")
plt.tight_layout()
plt.show()

# Data augmentation definition
data_augmentation = keras.Sequential([
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(0.05),
    layers.RandomZoom(0.10),
    layers.RandomContrast(0.10)
], name="data_augmentation")

# Base model loading and configuration
base_model = EfficientNetB0(
    include_top=False,
    weights="imagenet",
    input_shape=(224, 224, 3)
)
base_model.trainable = False
print("Base model loaded successfully.")
print("Number of layers:", len(base_model.layers))

# Model architecture definition
inputs = keras.Input(shape=(224, 224, 3))
x = data_augmentation(inputs)
x = base_model(x, training=False)
x = layers.GlobalAveragePooling2D()(x)
x = layers.BatchNormalization()(x)
x = layers.Dropout(0.4)(x)
x = layers.Dense(
    128,
    activation="relu"
)(x)
x = layers.Dropout(0.3)(x)
outputs = layers.Dense(
    NUM_CLASSES,
    activation="softmax"
)(x)
model = keras.Model(
    inputs,
    outputs,
    name="Alzheimer_EfficientNetB0"
)
model.summary()

# Model compilation
model.compile(
    optimizer=keras.optimizers.Adam(
        learning_rate=1e-3
    ),
    loss="categorical_crossentropy",
    metrics=[
        "accuracy"
    ]
)
print("Model compiled successfully.")

# Callbacks definition
callbacks = [
    EarlyStopping(
        monitor="val_loss",
        patience=4,
        restore_best_weights=True,
        verbose=1
    ),
    ReduceLROnPlateau(
        monitor="val_loss",
        factor=0.2,
        patience=2,
        min_lr=1e-7,
        verbose=1
    ),
    ModelCheckpoint(
        "/content/best_alzheimer_model.keras",
        monitor="val_accuracy",
        save_best_only=True,
        verbose=1
    )
]

# Model training
history_initial = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=EPOCHS_INITIAL,
    callbacks=callbacks
)
# Out:
# TensorFlow version: 2.20.0
# Train directory exists: False
# Test directory exists: False
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_696/1437618348.py in <cell line: 0>()
#      26
#      27 # Dataset loading
# ---> 28 train_ds = tf.keras.utils.image_dataset_from_directory(
#      29     TRAIN_DIR,
#      30     validation_split=0.20,
#
# /usr/local/lib/python3.13/dist-packages/keras/src/utils/image_dataset_utils.py in image_dataset_from_directory(directory, labels, label_mode, class_names, color_mode, batch_size, image_size, shuffle, seed, validation_split, subset, interpolation, follow_links, crop_to_aspect_ratio, pad_to_aspect_ratio, data_format, format, verbose)
#     263     if seed is None:
#     264         seed = np.random.randint(1e6)
# --> 265     image_paths, labels, class_names = dataset_utils.index_directory(
#     266         directory,
# ...

# %% [markdown]
# ### Training History and Model Evaluation
#
# Now that the model has been trained, let's visualize its performance during training and evaluate it on the test set.

# %%
# Plot training and validation accuracy and loss
acc = history_initial.history['accuracy']
val_acc = history_initial.history['val_accuracy']

loss = history_initial.history['loss']
val_loss = history_initial.history['val_loss']

epochs_range = range(EPOCHS_INITIAL)

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
# Evaluate the model on the test dataset
loss, accuracy = model.evaluate(test_ds)
print(f"Test Loss: {loss:.4f}")
print(f"Test Accuracy: {accuracy:.4f}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_696/532752402.py in <cell line: 0>()
#       1 # Evaluate the model on the test dataset
# ----> 2 loss, accuracy = model.evaluate(test_ds)
#       3 print(f"Test Loss: {loss:.4f}")
#       4 print(f"Test Accuracy: {accuracy:.4f}")
#
# NameError: name 'model' is not defined
